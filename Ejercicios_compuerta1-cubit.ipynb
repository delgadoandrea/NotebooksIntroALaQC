# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, assemble, Aer, IBMQ, execute
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram, plot_state_qsphere

# %% [markdown]
#     qc.x(0)    # rotation by Pi around the x-axis
#     qc.y(0)    # rotation by Pi around the y-axis
#     qc.z(0)    # rotation by Pi around the z-axis
#     qc.s(0)    # rotation by Pi/2 around the z-axis
#     qc.sdg(0)  # rotation by -Pi/2 around the z-axis
#     qc.h(0)    # rotation by Pi around an axis located halfway between x and z

# %%
def ejecutar_circuito_sv(quantum_circuit):
    statevector_simulator = Aer.get_backend('statevector_simulator')
    result = execute(quantum_circuit, statevector_simulator).result()
    statevector_results = result.get_statevector(quantum_circuit)
    circuit_diagram = quantum_circuit.draw()
    q_sphere = plot_state_qsphere(statevector_results)
    return statevector_results, circuit_diagram, q_sphere

# %% [markdown]
# Como ejecutar un bit flip? |0> -> |1>?

# %%
qc = QuantumCircuit(1)
qc.x(0)

# %%
result, img, qsphere = ejecutar_circuito_sv(qc)

# %%
qsphere

# %% [markdown]
# Transformar |0> -> |+> = 1\sqrt(2)(|0>+|1>)?

# %%
qc2 = QuantumCircuit(1)

# %%
qc2.h(0)

# %%
result2, img2, qsphere2 = ejecutar_circuito_sv(qc2)

# %%
qsphere2

# %% [markdown]
# Transformar |0> -> |-> = 1\sqrt(2)(|0>-|1>)?

# %%
qc3 = QuantumCircuit(1)

# %%
qc3.x(0)
qc3.h(0)

# %%
result3, img3, qsphere3 = ejecutar_circuito_sv(qc3)

# %%
result3
# Out:
# array([ 0.70710678+0.00000000e+00j, -0.70710678+8.65956056e-17j])

# %%
qsphere3

# %% [markdown]
# Transformar |0> -> |-i> = 1\sqrt(2)(|0>-i|1>)?
# Transformar |0> -> |-> = 1\sqrt(2)(|0>-|1>)?

# %%
qc4 = QuantumCircuit(1)

# %%
qc4.x(0)
qc4.z(0)
qc4.s(0)

# %%
result4, img4, qsphere4 = ejecutar_circuito_sv(qc4)

# %%
result3
# Out:
# array([ 0.70710678+0.00000000e+00j, -0.70710678+8.65956056e-17j])

# %%
result4
# Out:
# array([ 4.32978028e-17+4.32978028e-17j, -1.11022302e-16-1.00000000e+00j])

# %%
qsphere4

# %%
qc5 = QuantumCircuit(1)

# %%
import numpy as np

pi = np.pi

# %%
qc5.rx(pi/2,0)

# %%
result5, img5, qsphere5 = ejecutar_circuito_sv(qc5)

# %%
result5
# Out:
# array([0.70710678+0.j        , 0.        -0.70710678j])

# %%
qsphere5

# %%
state = Statevector.from_instruction(qc5)

# %%
plot_bloch_multivector(state)

# %%
def defloat_number(cmplx):
    r = lambda x : round(x, 5)
    return complex(r(cmplx.real), r(cmplx.imag))

def defloat_vector(vector):
    return list(map(defloat_number, vector))
